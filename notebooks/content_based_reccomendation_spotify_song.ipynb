# %%
import kagglehub
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
path = kagglehub.dataset_download("undefinenull/million-song-dataset-spotify-lastfm")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/million-song-dataset-spotify-lastfm

# %%
data_path = Path(path)

# %%
songs_path = data_path / 'Music Info.csv'
user_path = data_path / 'User Listening Hisrory.csv'

# %%
df_songs = pd.read_csv(songs_path)

# %%
df_songs.head()
# Out:
#              track_id             name           artist  \
# 0  TRIOREW128F424EAF0   Mr. Brightside      The Killers
# 1  TRRIVDJ128F429B0E8       Wonderwall            Oasis
# 2  TROUVHL128F426C441  Come as You Are          Nirvana
# 3  TRUEIND128F93038C4      Take Me Out  Franz Ferdinand
# 4  TRLNZBD128F935E4D8            Creep        Radiohead
#
#                                  spotify_preview_url              spotify_id  \
# 0  https://p.scdn.co/mp3-preview/4d26180e6961fd46...  09ZQ5TmUG8TSL56n0knqrj
# 1  https://p.scdn.co/mp3-preview/d012e536916c927b...  06UfBBDISthj1ZJAtX4xjj
# 2  https://p.scdn.co/mp3-preview/a1c11bb1cb231031...  0keNu0t0tqsWtExGM3nT1D
# 3  https://p.scdn.co/mp3-preview/399c401370438be4...  0ancVQ9wEcHVd0RrGICTE4
# 4  https://p.scdn.co/mp3-preview/e7eb60e9466bc3a2...  01QoK9DA7VTeTSE3MNzp4I
#
#                                                 tags genre  year  duration_ms  \
# 0  rock, alternative, indie, alternative_rock, in...   NaN  2004       222200
# ...

# %%
df_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50683 entries, 0 to 50682
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   track_id             50683 non-null  object
#  1   name                 50683 non-null  object
#  2   artist               50683 non-null  object
#  3   spotify_preview_url  50683 non-null  object
#  4   spotify_id           50683 non-null  object
#  5   tags                 49556 non-null  object
#  6   genre                22348 non-null  object
#  7   year                 50683 non-null  int64
#  8   duration_ms          50683 non-null  int64
#  9   danceability         50683 non-null  float64
#  10  energy               50683 non-null  float64
#  11  key                  50683 non-null  int64
#  12  loudness             50683 non-null  float64
#  13  mode                 50683 non-null  int64
#  14  speechiness          50683 non-null  float64
# ...

# %%
df_songs.isna().sum()
# Out:
# track_id                   0
# name                       0
# artist                     0
# spotify_preview_url        0
# spotify_id                 0
# tags                    1127
# genre                  28335
# year                       0
# duration_ms                0
# danceability               0
# energy                     0
# key                        0
# loudness                   0
# mode                       0
# speechiness                0
# acousticness               0
# instrumentalness           0
# liveness                   0
# valence                    0
# tempo                      0
# time_signature             0
# dtype: int64

# %%
df.isna().mean().sort_values(ascending=False).head(2).mul(100)
# Out:
# artist    0.0
# tags      0.0
# dtype: float64

# %%
df_songs.duplicated(subset='spotify_id').sum()
# Out:
# np.int64(9)

# %%
df_songs.drop_duplicates(subset='spotify_id', inplace=True)

# %%
df_songs.reset_index(drop=True, inplace=True)

# %%
df_songs.columns
# Out:
# Index(['track_id', 'name', 'artist', 'spotify_preview_url', 'spotify_id',
#        'tags', 'genre', 'year', 'duration_ms', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
col_to_remove = ['track_id','name','spotify_preview_url',"spotify_id",'genre']

# %%
df = df_songs.drop(columns=col_to_remove,)

# %%
df.fillna({"tags":"no tags"},inplace= True)

# %%
df.isna().sum()
# Out:
# artist              0
# tags                0
# year                0
# duration_ms         0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# dtype: int64

# %%
df.loc[:,'tags'].str.lower().str.split(",").explode().str.strip().value_counts()
# Out:
# tags
# rock            10681
# indie            7284
# electronic       6592
# alternative      6271
# pop              4650
#                 ...
# dark_ambient      602
# japanese          489
# polish            411
# j_pop             213
# russian           127
# Name: count, Length: 101, dtype: int64

# %%
df.loc[:,'tags'].str.lower().str.split(",").explode().str.strip().value_counts().loc[lambda x: x>=1000]
# Out:
# tags
# rock            10681
# indie            7284
# electronic       6592
# alternative      6271
# pop              4650
#                 ...
# ska              1088
# gothic_metal     1072
# grindcore        1040
# french           1018
# nu_metal         1006
# Name: count, Length: 86, dtype: int64

# %%
# !pip install category_encoders

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler,OneHotEncoder
from category_encoders.count import CountEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.compose import ColumnTransformer

# %%
df.shape
# Out:
# (50674, 16)

# %%
df.columns
# Out:
# Index(['artist', 'tags', 'year', 'duration_ms', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
# cols to be transformed

frequency_encode_cols = ['year']
ohe_cols = ['artist', 'time_signature', 'key']
tfidf_cols = 'tags'
standard_scale_cols = ['duration_ms','loudness','tempo']
min_max_scale_cols = ['danceability', 'energy','speechiness', 'acousticness','instrumentalness', 'liveness', 'valence']

# %%
transformer = ColumnTransformer(transformers = [
    ("frequency_encode",CountEncoder(normalize=True,return_df=True),frequency_encode_cols),
    ("ohe",OneHotEncoder(handle_unknown='ignore'),ohe_cols),
    ("tfidf",TfidfVectorizer(max_features=85),tfidf_cols),
    ("standard_scale",StandardScaler(),standard_scale_cols),
    ("min_max_scale",MinMaxScaler(),min_max_scale_cols)
],remainder='passthrough',n_jobs=-1,force_int_remainder_cols=False)

# %%
transformer.fit(df)
# Out:
# ColumnTransformer(force_int_remainder_cols=False, n_jobs=-1,
#                   remainder='passthrough',
#                   transformers=[('frequency_encode',
#                                  CountEncoder(combine_min_nan_groups=True,
#                                               normalize=True),
#                                  ['year']),
#                                 ('ohe', OneHotEncoder(handle_unknown='ignore'),
#                                  ['artist', 'time_signature', 'key']),
#                                 ('tfidf', TfidfVectorizer(max_features=85),
#                                  'tags'),
#                                 ('standard_scale', StandardScaler(),
#                                  ['duration_ms', 'loudness', 'tempo']),
#                                 ('min_max_scale', MinMaxScaler(),
#                                  ['danceability', 'energy', 'speechiness',
#                                   'acousticness', 'instrumentalness',
# ...

# %%
transformed_df = transformer.transform(df)

# %%
transformed_df.shape
# Out:
# (50674, 8431)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
df_songs[df['artist']=='Shakira']
# Out:
#                  track_id                            name   artist  \
# 1025   TRLWDVU128F932B093              Whenever, Wherever  Shakira
# 2068   TRILOWN128F426080F         Underneath Your Clothes  Shakira
# 2205   TRXLMFJ12903CC06F7                        She Wolf  Shakira
# 2469   TRSQAWU128F92EA20F                      La Tortura  Shakira
# 3373   TRINUNP12903CD84D9                    Did It Again  Shakira
# 4318   TROLUWR128F92E5858                  Te Dejo Madrid  Shakira
# 4599   TRLNLES128F932DA8E                            Fool  Shakira
# 4617   TRUIPZL12903CA0BFE                           Rules  Shakira
# 6046   TRAAKDG128F42A0ECB                  Hips Don't Lie  Shakira
# 6818   TRBAHID128F4278EAF               Objection (Tango)  Shakira
# 7007   TRHEBDB128F92E9FC0                    Don't Bother  Shakira
# 11904  TRADBSW128F933A7A8                            Loba  Shakira
# 12305  TRYFVKK128F4240FE8                        Why Wait  Shakira
# ...

# %%
song_input = df[df_songs['name']=="Hips Don't Lie"]
song_input
# Out:
#        artist                                               tags  year  \
# 6046  Shakira  pop, female_vocalists, singer_songwriter, danc...  2001
#
#       duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 6046       217453         0.777    0.82   10    -5.867     0       0.0734
#
#       acousticness  instrumentalness  liveness  valence    tempo  \
# 6046         0.284               0.0      0.43     0.76  100.003
#
#       time_signature
# 6046               4

# %%
input_vector = transformer.transform(song_input)

# %%
similarity_scores = cosine_similarity(input_vector,transformed_df)

# %%
top_ten_songs = similarity_scores.argsort()[0][-11:][::-1]

# %%
top_ten_songs
# Out:
# array([ 6046,  1025,  6843, 17254, 21474, 21532, 17191,  7146,  7303,
#        14914])

# %%
df_songs.iloc[top_ten_songs]
# Out:
#                  track_id                name              artist  \
# 6046   TRAAKDG128F42A0ECB      Hips Don't Lie             Shakira
# 1025   TRLWDVU128F932B093  Whenever, Wherever             Shakira
# 6843   TRFNBSP128F93098D6      My Prerogative      Britney Spears
# 17254  TRLOIPU128F9353348               Aloha                Møme
# 21474  TRDCCNE128F93186BB         Say My Name        David Guetta
# 21532  TRPQULA128E0786DE4     Always Too Late               Annie
# 17191  TRXRFBY128F93234B5   Hoedown Throwdown         Miley Cyrus
# 7146   TRNGAUB128F92E65FF      I'm Outta Love           Anastacia
# 7303   TRAUJRL128F9302062     Whatever U Like  Nicole Scherzinger
# 14914  TRWCCEX128F934F68C            AM to PM    Christina Milian
#
#                                      spotify_preview_url  \
# 6046   https://p.scdn.co/mp3-preview/3859547944f57cfb...
# 1025   https://p.scdn.co/mp3-preview/09ddeb4ae33ee6e8...
# 6843   https://p.scdn.co/mp3-preview/9140e378563ce3e0...
# ...

# %%
def recommend_songs(song_name, song_df, transformed_df, k):
  """
  Recommends k songs based on the similarity to a given song.

  Args:
    song_name: The name of the song to get recommendations for.
    song_df: The original dataframe containing song information.
    transformed_df: The transformed dataframe used for similarity calculation.
    k: The number of recommendations to return.

  Returns:
    A pandas DataFrame containing the top k recommended songs.
  """
  song_input = song_df[song_df['name'] == song_name]
  song_index = song_input.index[0]

  if song_input.empty:
    print(f"Song '{song_name}' not found in the dataset.")


  input_vector = transformed_df[song_index].reshape(1, -1)
  similarity_scores = cosine_similarity(input_vector,transformed_df)


  top_k_indices = similarity_scores.argsort()[0][-(k+1):][::-1]


  recommended_indices = [i for i in top_k_indices if song_df.iloc[i]['name'] != song_name]

  # Return the top k recommended songs
  top_k_songs =  song_df.iloc[recommended_indices[:k]]
  top_songs =  top_k_songs[['name','artist','spotify_preview_url']].reset_index(drop=True)
  return top_songs

# %%
recommended_songs_df = recommend_songs("Hips Don't Lie", df_songs, transformed_df, 10)
recommended_songs_df
# Out:
#                  name              artist  \
# 0  Whenever, Wherever             Shakira
# 1      My Prerogative      Britney Spears
# 2               Aloha                Møme
# 3         Say My Name        David Guetta
# 4     Always Too Late               Annie
# 5   Hoedown Throwdown         Miley Cyrus
# 6      I'm Outta Love           Anastacia
# 7     Whatever U Like  Nicole Scherzinger
# 8            AM to PM    Christina Milian
# 9          Wonderland       Natalia Kills
#
#                                  spotify_preview_url
# 0  https://p.scdn.co/mp3-preview/09ddeb4ae33ee6e8...
# 1  https://p.scdn.co/mp3-preview/9140e378563ce3e0...
# 2  https://p.scdn.co/mp3-preview/c4c1768c0f2beab9...
# 3  https://p.scdn.co/mp3-preview/89e0ed2f21273e77...
# 4  https://p.scdn.co/mp3-preview/7f2f89b82ed206ea...
# 5  https://p.scdn.co/mp3-preview/09a6a3b11b6f628d...
# 6  https://p.scdn.co/mp3-preview/feda5c101a29c254...
# 7  https://p.scdn.co/mp3-preview/6b3e93d2c5472ea7...
# ...
